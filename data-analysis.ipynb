# %%
from statistics import correlation

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import glob
import os

plt.rcParams['font.family'] = 'DejaVu Sans'

# %% [markdown]
# # Merging data

# %%
csv_files = glob.glob(os.path.join("emissions-data", "*.csv"))
emissions = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)
emissions
# Out:
#                    Datetime (UTC)  Country Zone name Zone id  \
# 0      2021-01-01T00:00:00.000000  Denmark   Denmark      DK
# 1      2021-01-01T01:00:00.000000  Denmark   Denmark      DK
# 2      2021-01-01T02:00:00.000000  Denmark   Denmark      DK
# 3      2021-01-01T03:00:00.000000  Denmark   Denmark      DK
# 4      2021-01-01T04:00:00.000000  Denmark   Denmark      DK
# ...                           ...      ...       ...     ...
# 43819  2025-12-31T19:00:00.000000  Denmark   Denmark      DK
# 43820  2025-12-31T20:00:00.000000  Denmark   Denmark      DK
# 43821  2025-12-31T21:00:00.000000  Denmark   Denmark      DK
# 43822  2025-12-31T22:00:00.000000  Denmark   Denmark      DK
# 43823  2025-12-31T23:00:00.000000  Denmark   Denmark      DK
#
#        Carbon intensity gCO₂eq/kWh (direct)  \
# 0                                    124.66
# 1                                    111.30
# 2                                    108.22
# 3                                    111.48
# 4                                    118.55
# ...                                     ...
# 43819                                103.88
# 43820                                106.39
# 43821                                 87.89
# 43822                                 77.02
# 43823                                 70.31
#
#        Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 0                                        194.25
# 1                                        182.42
# 2                                        179.20
# 3                                        183.04
# 4                                        191.54
# ...                                         ...
# 43819                                    170.66
# 43820                                    170.86
# 43821                                    140.17
# 43822                                    123.40
# 43823                                    110.38
#
#        Carbon-free energy percentage (CFE%)  \
# 0                                     81.99
# 1                                     83.66
# 2                                     83.96
# 3                                     83.55
# 4                                     82.64
# ...                                     ...
# 43819                                 85.19
# 43820                                 84.76
# 43821                                 87.42
# 43822                                 88.99
# 43823                                 90.29
#
#        Renewable energy percentage (RE%) Data source  Data estimated  \
# 0                                  69.99   entsoe.eu           False
# 1                                  70.19   entsoe.eu           False
# 2                                  70.10   entsoe.eu           False
# 3                                  69.64   entsoe.eu           False
# 4                                  69.15   entsoe.eu           False
# ...                                  ...         ...             ...
# 43819                              80.95   entsoe.eu           False
# 43820                              80.49   entsoe.eu           False
# 43821                              80.60   entsoe.eu           False
# 43822                              82.10   entsoe.eu           False
# 43823                              82.84   entsoe.eu           False
#
#       Data estimation method
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 43819                    NaN
# 43820                    NaN
# 43821                    NaN
# 43822                    NaN
# 43823                    NaN
#
# [43824 rows x 11 columns]

# %% [markdown]
# # Data Cleaning
#
# ## Estimated values

# %%
estimated = emissions[emissions["Data estimated"] == True]
estimated
# Out:
#                    Datetime (UTC)  Country Zone name Zone id  \
# 9728   2022-02-10T08:00:00.000000  Denmark   Denmark      DK
# 9729   2022-02-10T09:00:00.000000  Denmark   Denmark      DK
# 9730   2022-02-10T10:00:00.000000  Denmark   Denmark      DK
# 9731   2022-02-10T11:00:00.000000  Denmark   Denmark      DK
# 9732   2022-02-10T12:00:00.000000  Denmark   Denmark      DK
# ...                           ...      ...       ...     ...
# 41672  2025-10-03T08:00:00.000000  Denmark   Denmark      DK
# 41673  2025-10-03T09:00:00.000000  Denmark   Denmark      DK
# 41674  2025-10-03T10:00:00.000000  Denmark   Denmark      DK
# 41675  2025-10-03T11:00:00.000000  Denmark   Denmark      DK
# 41676  2025-10-03T12:00:00.000000  Denmark   Denmark      DK
#
#        Carbon intensity gCO₂eq/kWh (direct)  \
# 9728                                 175.33
# 9729                                 136.80
# 9730                                 134.73
# 9731                                 128.75
# 9732                                 127.22
# ...                                     ...
# 41672                                 65.44
# 41673                                 60.12
# 41674                                 52.02
# 41675                                 46.86
# 41676                                 46.54
#
#        Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 9728                                     241.05
# 9729                                     193.53
# 9730                                     190.94
# 9731                                     183.68
# 9732                                     182.20
# ...                                         ...
# 41672                                    109.18
# 41673                                    100.75
# 41674                                     90.91
# 41675                                     83.65
# 41676                                     81.46
#
#        Carbon-free energy percentage (CFE%)  \
# 9728                                  76.14
# 9729                                  80.57
# 9730                                  80.83
# 9731                                  81.76
# 9732                                  82.06
# ...                                     ...
# 41672                                 90.60
# 41673                                 91.53
# 41674                                 92.70
# 41675                                 93.40
# 41676                                 93.46
#
#        Renewable energy percentage (RE%) Data source  Data estimated  \
# 9728                               72.34   entsoe.eu            True
# 9729                               76.28   entsoe.eu            True
# 9730                               75.87   entsoe.eu            True
# 9731                               76.87   entsoe.eu            True
# 9732                               77.01   entsoe.eu            True
# ...                                  ...         ...             ...
# 41672                              90.16   entsoe.eu            True
# 41673                              90.07   entsoe.eu            True
# 41674                              91.19   entsoe.eu            True
# 41675                              92.21   entsoe.eu            True
# 41676                              91.61   entsoe.eu            True
#
#               Data estimation method
# 9728   ESTIMATED_FORECASTS_HIERARCHY
# 9729   ESTIMATED_FORECASTS_HIERARCHY
# 9730   ESTIMATED_FORECASTS_HIERARCHY
# 9731   ESTIMATED_FORECASTS_HIERARCHY
# 9732   ESTIMATED_FORECASTS_HIERARCHY
# ...                              ...
# 41672  ESTIMATED_FORECASTS_HIERARCHY
# 41673  ESTIMATED_FORECASTS_HIERARCHY
# 41674  ESTIMATED_FORECASTS_HIERARCHY
# 41675  ESTIMATED_FORECASTS_HIERARCHY
# 41676  ESTIMATED_FORECASTS_HIERARCHY
#
# [306 rows x 11 columns]

# %% [markdown]
# ## Dropping columns

# %%
emissions = emissions.drop(columns=["Data estimated", "Country", "Zone name", "Data source", "Data estimation method"])
emissions
# Out:
#                    Datetime (UTC) Zone id  \
# 0      2021-01-01T00:00:00.000000      DK
# 1      2021-01-01T01:00:00.000000      DK
# 2      2021-01-01T02:00:00.000000      DK
# 3      2021-01-01T03:00:00.000000      DK
# 4      2021-01-01T04:00:00.000000      DK
# ...                           ...     ...
# 43819  2025-12-31T19:00:00.000000      DK
# 43820  2025-12-31T20:00:00.000000      DK
# 43821  2025-12-31T21:00:00.000000      DK
# 43822  2025-12-31T22:00:00.000000      DK
# 43823  2025-12-31T23:00:00.000000      DK
#
#        Carbon intensity gCO₂eq/kWh (direct)  \
# 0                                    124.66
# 1                                    111.30
# 2                                    108.22
# 3                                    111.48
# 4                                    118.55
# ...                                     ...
# 43819                                103.88
# 43820                                106.39
# 43821                                 87.89
# 43822                                 77.02
# 43823                                 70.31
#
#        Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 0                                        194.25
# 1                                        182.42
# 2                                        179.20
# 3                                        183.04
# 4                                        191.54
# ...                                         ...
# 43819                                    170.66
# 43820                                    170.86
# 43821                                    140.17
# 43822                                    123.40
# 43823                                    110.38
#
#        Carbon-free energy percentage (CFE%)  Renewable energy percentage (RE%)
# 0                                     81.99                              69.99
# 1                                     83.66                              70.19
# 2                                     83.96                              70.10
# 3                                     83.55                              69.64
# 4                                     82.64                              69.15
# ...                                     ...                                ...
# 43819                                 85.19                              80.95
# 43820                                 84.76                              80.49
# 43821                                 87.42                              80.60
# 43822                                 88.99                              82.10
# 43823                                 90.29                              82.84
#
# [43824 rows x 6 columns]

# %% [markdown]
# # Analysis
# ## Correlation Matrix

# %%
correlation_matrix = emissions[
    ["Carbon intensity gCO₂eq/kWh (direct)",
     "Carbon intensity gCO₂eq/kWh (Life cycle)",
     "Carbon-free energy percentage (CFE%)",
     "Renewable energy percentage (RE%)"]
].corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Carbon intensity over the years

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
df = emissions.copy()
df["Datetime (UTC)"] = pd.to_datetime(df["Datetime (UTC)"])
df = df.sort_values("Datetime (UTC)").reset_index(drop=True)


df["hour"] = df["Datetime (UTC)"].dt.hour
df["dayofweek"] = df["Datetime (UTC)"].dt.dayofweek
df["month"] = df["Datetime (UTC)"].dt.month
df["year"] = df["Datetime (UTC)"].dt.year

df = df.set_index('Datetime (UTC)')

fig, axes = plt.subplots(4, 1, figsize=(6, 14), sharey=True, constrained_layout=True)

sns.boxplot(
    data=df,
    x="year",
    y="Carbon intensity gCO₂eq/kWh (direct)",
    ax=axes[0]
)
axes[0].set_xlabel("Year")
axes[0].set_title("Carbon Intensity over the Year")

sns.boxplot(
    data=df,
    x="month",
    y="Carbon intensity gCO₂eq/kWh (direct)",
    ax=axes[1]
)
axes[1].set_xlabel("Month")
axes[1].set_title("Monthly Distribution Carbon Intensity")

sns.boxplot(
    data=df,
    x="hour",
    y="Carbon intensity gCO₂eq/kWh (direct)",
    ax=axes[2]
)
axes[2].set_xlabel("Hour")
axes[2].set_title("Carbon Intensity Distribution by the Hour")

sns.boxplot(
    data=df,
    x="dayofweek",
    y="Carbon intensity gCO₂eq/kWh (direct)",
    ax=axes[3]
)
axes[3].set_xticks(range(7))
axes[3].set_xticklabels(days)
axes[3].set_xlabel("Day of Week")
axes[3].set_title("Carbon Intensity Distribution by Day of Week")

plt.show()

# %%
numeric_df = df.select_dtypes(include='number')

fig, ax = plt.subplots(figsize=(12, 5))

for year, data in numeric_df.groupby(numeric_df.index.year):
    weekly = data.resample('W').mean()

    # Convert to week-of-year based on day-of-year
    weekly['week'] = ((weekly.index.dayofyear - 1) // 7) + 1

    weekly = weekly.sort_values('week')

    ax.plot(
        weekly['week'],
        weekly['Carbon intensity gCO₂eq/kWh (direct)'],
        label=str(year)
    )

ax.set_xlim(1, 53)
ax.set_xlabel("Week of Year")
ax.set_ylabel("Carbon intensity (gCO$_2$eq/kWh)")
ax.set_title("Weekly Carbon Intensity Comparison (2021–2025)")
ax.legend(title="Year")

plt.tight_layout()
plt.show()
